# %% [markdown]
# ### Denoising Autoencoders And Where To Find Them
#
# Today we're going to train deep autoencoders and deploy them to faces and search for similar images.
#
# Our new test subjects are human faces from the [lfw dataset](http://vis-www.cs.umass.edu/lfw/).

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# **Collab setting**

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/HW3
# %ls
# Out:
# /content/gdrive/My Drive/Colab Notebooks/HW3
# BBBC018_v1_images-fixed/
# BBBC018_v1_outlines/
# data.zip
# homework03_part1_both.ipynb
# homework03_part2_autoencoders_basic.ipynb
# homework03_part2_vae_advanced.ipynb
# homework03_part3a_gan_advanced.ipynb
# homework03_part3b_prd_score_advanced.ipynb
# homework03_part3_gan_basic.ipynb
# lfw_dataset.py
# lfw-deepfunneled/
# linear.png
# __pycache__/
# simple_1d_gan_pytorch.ipynb

# %%
# if you're running in colab,
# 1. go to Runtime -> Change Runtimy Type -> GPU
# 2. uncomment this:
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/hw3_19/homework03/lfw_dataset.py -O lfw_dataset.py
# Out:
# --2019-04-27 14:01:06--  https://raw.githubusercontent.com/yandexdataschool/Practical_DL/hw3_19/homework03/lfw_dataset.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2734 (2.7K) [text/plain]
# Saving to: ‘lfw_dataset.py’
#
# lfw_dataset.py      100%[===================>]   2.67K  --.-KB/s    in 0s
#
# 2019-04-27 14:01:06 (13.0 MB/s) - ‘lfw_dataset.py’ saved [2734/2734]

# %%
import torch
import numpy as np

from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


EPOCHS = 100
BATCH_SIZE = 32
LEARNING_RATE = 1e-3

LATENT_DIMENSION = 4
BATCH_SIZE = 32

device = torch.device("cuda")

# %%
import numpy as np
from lfw_dataset import fetch_lfw_dataset
from sklearn.model_selection import train_test_split
X, attr = fetch_lfw_dataset(use_raw=True,dimx=38,dimy=38)
X = X.transpose([0,3,1,2]).astype('float32') / 256.0

img_shape = X.shape[1:]

X_train, X_test = train_test_split(X, test_size=0.1,random_state=42)
# Out:
# images not found, donwloading...
# extracting...
# done
# attributes not found, downloading...
# done

# %%
X_train_tensor = torch.from_numpy(X_train).type(torch.DoubleTensor)
X_test_tensor = torch.Tensor(X_test).type(torch.DoubleTensor)

# %%
img_shape
# Out:
# (3, 38, 38)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.title('sample image')
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(X[i].transpose([1,2,0]))

print("X shape:",X.shape)
print("attr shape:",attr.shape)
# Out:
# X shape: (13143, 3, 38, 38)
# attr shape: (13143, 73)

# %% [markdown]
# ### Autoencoder architecture
#
# Let's design autoencoder as a single lasagne network, going from input image through bottleneck into the reconstructed image.
#
# <img src="http://nghiaho.com/wp-content/uploads/2012/12/autoencoder_network1.png" width=640px>

# %% [markdown]
# ## First step: PCA
#
# Principial Component Analysis is a popular dimensionality reduction method.
#
# Under the hood, PCA attempts to decompose object-feature matrix $X$ into two smaller matrices: $W$ and $\hat W$ minimizing _mean squared error_:
#
# $$\|(X W) \hat{W} - X\|^2_2 \to_{W, \hat{W}} \min$$
# - $X \in \mathbb{R}^{n \times m}$ - object matrix (**centered**);
# - $W \in \mathbb{R}^{m \times d}$ - matrix of direct transformation;
# - $\hat{W} \in \mathbb{R}^{d \times m}$ - matrix of reverse transformation;
# - $n$ samples, $m$ original dimensions and $d$ target dimensions;
#
# In geometric terms, we want to find d axes along which most of variance occurs. The "natural" axes, if you wish.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/9/90/PCA_fish.png/256px-PCA_fish.png)
#
#
# PCA can also be seen as a special case of an autoencoder.
#
# * __Encoder__: X -> Dense(d units) -> code
# * __Decoder__: code -> Dense(m units) -> X
#
# Where Dense is a fully-connected layer with linear activaton:   $f(X) = W \cdot X + \vec b $
#
#
# Note: the bias term in those layers is responsible for "centering" the matrix i.e. substracting mean.

# %%
# this class corresponds to view-function and may be used as a reshape layer 

class View(nn.Module):
    def __init__(self, *shape):
        super(View, self).__init__()
        self.shape = shape
    def forward(self, input):
        return input.view(input.size(0),*self.shape)

# %%
#code from HW 2
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

# %%
class pca_autoencoder(nn.Module):
    """
    Here we define a simple linear autoencoder as described above.
    We also flatten and un-flatten data to be compatible with image shapes
    """
    
    def __init__(self, code_size=32):
        super(pca_autoencoder, self).__init__()
        self.enc = nn.Sequential()
        self.enc.add_module('flatten',Flatten())
        self.enc.add_module('enc',nn.Linear(38*38*3,code_size,bias=True))
        
        
        self.dec =nn.Sequential()
        self.dec.add_module('dec',nn.Linear(code_size,38*38*3,bias=True))
        self.dec.add_module('view',View(3,38,38))
    
    def batch_loss(self, batch):
        reconstruction = self.enc(batch)
        reconstruction=self.dec(reconstruction)
        return torch.mean((batch - reconstruction)**2)

# %% [markdown]
# ### Train the model
#
# As usual, iterate minibatches of data and call train_step, then evaluate loss on validation data.
#
# __Note to py2 users:__ you can safely drop `flush=True` from any code below.

# %%
def train(model, dataset, num_epoch=32):
    model.double()
    model.to(device)
    gd = optim.Adamax(model.parameters(), lr=0.002)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
    losses = []
    for epoch in range(num_epoch):
        for i, (batch) in enumerate(dataloader):
            gd.zero_grad()
            loss = model.batch_loss(batch.cuda())
            (loss).backward()
            losses.append(loss.detach().cpu().numpy())
            gd.step()
            gd.zero_grad()
        print("#%i, Train loss: %.7f"%(epoch+1,np.mean(losses)),flush=True)

# %%
def visualize(img, model):
    """Draws original, encoded and decoded images"""
    code = model.enc(img[None].cuda())
    reco = model.dec(code)

    plt.subplot(1,3,1)
    plt.title("Original")
    plt.imshow(img.cpu().numpy().transpose([1, 2, 0]).clip(0, 1))

    plt.subplot(1,3,2)
    plt.title("Code")
    plt.imshow(code.cpu().detach().numpy().reshape([code.shape[-1] // 2, -1]))

    plt.subplot(1,3,3)
    plt.title("Reconstructed")
    plt.imshow(reco[0].cpu().detach().numpy().transpose([1, 2, 0]).clip(0, 1))
    plt.show()

# %%
aenc = pca_autoencoder()
train(aenc, X_train_tensor, 40)
# Out:
# #1, Train loss: 0.1475980
# #2, Train loss: 0.0854947
# #3, Train loss: 0.0640759
# #4, Train loss: 0.0533071
# #5, Train loss: 0.0468026
# #6, Train loss: 0.0424192
# #7, Train loss: 0.0392047
# #8, Train loss: 0.0366125
# #9, Train loss: 0.0344101
# #10, Train loss: 0.0325434
# #11, Train loss: 0.0309176
# #12, Train loss: 0.0294594
# #13, Train loss: 0.0281400
# #14, Train loss: 0.0269432
# #15, Train loss: 0.0258452
# #16, Train loss: 0.0248427
# #17, Train loss: 0.0239255
# #18, Train loss: 0.0230864
# #19, Train loss: 0.0223202
# #20, Train loss: 0.0216128
# #21, Train loss: 0.0209600
# #22, Train loss: 0.0203574
# #23, Train loss: 0.0198000
# #24, Train loss: 0.0192827
# #25, Train loss: 0.0187968
# #26, Train loss: 0.0183429
# #27, Train loss: 0.0179162
# #28, Train loss: 0.0175150
# #29, Train loss: 0.0171371
# #30, Train loss: 0.0167816
# #31, Train loss: 0.0164444
# #32, Train loss: 0.0161275
# #33, Train loss: 0.0158273
# #34, Train loss: 0.0155408
# #35, Train loss: 0.0152713
# #36, Train loss: 0.0150140
# #37, Train loss: 0.0147698
# #38, Train loss: 0.0145380
# #39, Train loss: 0.0143157
# #40, Train loss: 0.0141047

# %%
dataloader_test = DataLoader(X_test_tensor, batch_size=BATCH_SIZE, shuffle=True)
scores = []
for i, (batch) in enumerate(dataloader_test):
    scores.append(aenc.batch_loss(batch.cuda()).data.cpu().numpy())
print (np.mean(scores))
# Out:
# 0.006090843893199695

# %%
for i in range(5):
    img = X_test_tensor[i]
    visualize(img,aenc)

# %% [markdown]
# ### Going deeper
#
# PCA is neat but surely we can do better. This time we want you to build a deep autoencoder by... stacking more layers.
#
# In particular, your encoder and decoder should be at least 3 layers deep each. You can use any nonlinearity you want and any number of hidden units in non-bottleneck layers provided you can actually afford training it.
#
# ![layers](https://pbs.twimg.com/media/CYggEo-VAAACg_n.png:small)
#
# A few sanity checks:
# * There shouldn't be any hidden layer smaller than bottleneck (encoder output).
# * Don't forget to insert nonlinearities between intermediate dense layers.
# * Convolutional layers are good idea. To undo convolution use L.Deconv2D, pooling - L.UpSampling2D.
# * Adding activation after bottleneck is allowed, but not strictly necessary.

# %%
class pca_autoencoder_deep(nn.Module):
    def __init__(self,code_size=32):
        super(pca_autoencoder_deep, self).__init__()

        
        self.enc = nn.Sequential()
        self.enc.add_module('conv-1', nn.Conv2d(in_channels=3, out_channels=8, kernel_size=5, padding = 2))
        self.enc.add_module('relu', nn.ELU())
        
        self.enc.add_module('conv-2', nn.Conv2d(in_channels=8, out_channels=16, kernel_size=5, padding = 2))
        self.enc.add_module('rlu-2', nn.ELU())
        self.enc.add_module('pool', nn.MaxPool2d(2))
        self.enc.add_module('conv-3', nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, padding = 2))
        self.enc.add_module('flat', Flatten())
        self.enc.add_module('dense-1', nn.Linear(19 * 19 * 32, code_size))
        
        self.dec = nn.Sequential()
        self.dec.add_module('decocder', nn.Linear(code_size,32 * 19 * 19 ))
        self.dec.add_module('reshape', View(32, 19, 19))
        self.dec.add_module('conv-1', nn.ConvTranspose2d(in_channels=32, out_channels=16, kernel_size=5, padding = 2))
        self.dec.add_module('rlu-1', nn.ELU())
        self.dec.add_module('up',nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True))
        self.dec.add_module('conv-2', nn.ConvTranspose2d(in_channels=16, out_channels=8, kernel_size=5, padding = 2))
        self.dec.add_module('relu-2', nn.ELU())
        self.dec.add_module('conv-3', nn.ConvTranspose2d(in_channels=8, out_channels=3, kernel_size=5, padding = 2))
        
  
        

    def batch_loss(self, batch):
        reconstruction = self.dec(self.enc(batch))
        return torch.mean((batch - reconstruction)**2)

# %%
aenc_deep = pca_autoencoder_deep()
train(aenc_deep, X_train_tensor, 80)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/upsampling.py:129: UserWarning: nn.Upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.{} is deprecated. Use nn.functional.interpolate instead.".format(self.name))
# #1, Train loss: 0.0205463
# #2, Train loss: 0.0144941
# #3, Train loss: 0.0120001
# #4, Train loss: 0.0106143
# #5, Train loss: 0.0097325
# #6, Train loss: 0.0091106
# #7, Train loss: 0.0086550
# #8, Train loss: 0.0082982
# #9, Train loss: 0.0080168
# #10, Train loss: 0.0077762
# #11, Train loss: 0.0075828
# #12, Train loss: 0.0074188
# #13, Train loss: 0.0072748
# #14, Train loss: 0.0071467
# #15, Train loss: 0.0070326
# #16, Train loss: 0.0069296
# #17, Train loss: 0.0068347
# #18, Train loss: 0.0067460
# #19, Train loss: 0.0066651
# #20, Train loss: 0.0065882
# #21, Train loss: 0.0065166
# #22, Train loss: 0.0064481
# #23, Train loss: 0.0063852
# #24, Train loss: 0.0063250
# #25, Train loss: 0.0062679
# #26, Train loss: 0.0062143
# #27, Train loss: 0.0061627
# #28, Train loss: 0.0061147
# #29, Train loss: 0.0060685
# #30, Train loss: 0.0060245
# #31, Train loss: 0.0059825
# #32, Train loss: 0.0059417
# #33, Train loss: 0.0059036
# #34, Train loss: 0.0058665
# #35, Train loss: 0.0058312
# #36, Train loss: 0.0057973
# #37, Train loss: 0.0057644
# #38, Train loss: 0.0057328
# #39, Train loss: 0.0057022
# #40, Train loss: 0.0056728
# #41, Train loss: 0.0056442
# #42, Train loss: 0.0056166
# #43, Train loss: 0.0055894
# #44, Train loss: 0.0055635
# #45, Train loss: 0.0055383
# #46, Train loss: 0.0055138
# #47, Train loss: 0.0054901
# #48, Train loss: 0.0054674
# #49, Train loss: 0.0054451
# #50, Train loss: 0.0054233
# #51, Train loss: 0.0054023
# #52, Train loss: 0.0053816
# #53, Train loss: 0.0053615
# #54, Train loss: 0.0053421
# #55, Train loss: 0.0053229
# #56, Train loss: 0.0053043
# #57, Train loss: 0.0052863
# #58, Train loss: 0.0052684
# #59, Train loss: 0.0052510
# #60, Train loss: 0.0052341
# #61, Train loss: 0.0052175
# #62, Train loss: 0.0052013
# #63, Train loss: 0.0051855
# #64, Train loss: 0.0051700
# #65, Train loss: 0.0051548
# #66, Train loss: 0.0051399
# #67, Train loss: 0.0051253
# #68, Train loss: 0.0051111
# #69, Train loss: 0.0050973
# #70, Train loss: 0.0050834
# #71, Train loss: 0.0050701
# #72, Train loss: 0.0050570
# #73, Train loss: 0.0050439
# #74, Train loss: 0.0050311
# #75, Train loss: 0.0050187
# #76, Train loss: 0.0050064
# #77, Train loss: 0.0049942
# #78, Train loss: 0.0049824
# #79, Train loss: 0.0049709
# #80, Train loss: 0.0049593

# %% [markdown]
# Training may take long, it's okay.

# %% [markdown]
# **Check autoencoder shapes along different code_sizes. Check architecture of you encoder-decoder network is correct**

# %%
get_dim = lambda layer: np.prod(layer.output_shape[1:])
for code_size in [1,8,32,128,512,1024]:
    help_tensor = next(iter(DataLoader(X_train_tensor, batch_size=BATCH_SIZE)))
    model = pca_autoencoder_deep(code_size).to(device)
    encoder_out = model.enc(help_tensor.type('torch.FloatTensor').cuda())
    decoder_out = model.dec(encoder_out)
    print("Testing code size %i" % code_size)

    assert encoder_out.shape[1:]==torch.Size([code_size]),"encoder must output a code of required size"
    assert decoder_out.shape[1:]==img_shape,   "decoder must output an image of valid shape"

    assert (len(list(model.dec.children())) >= 6),  "decoder must contain at least 3 dense layers"

print("All tests passed!")
# Out:
# Testing code size 1
# Testing code size 8
# Testing code size 32
# Testing code size 128
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/upsampling.py:129: UserWarning: nn.Upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.{} is deprecated. Use nn.functional.interpolate instead.".format(self.name))
# Testing code size 512
# Testing code size 1024
# All tests passed!

# %% [markdown]
# __Hint:__ if you're getting "Encoder layer is smaller than bottleneck" error, use code_size when defining intermediate layers.
#
# For example, such layer may have code_size*2 units.

# %% [markdown]
# ** Lets check you model's score. You should beat value of 0.005 **

# %%
dataloader_test = DataLoader(X_test_tensor, batch_size=BATCH_SIZE, shuffle=True)
scores = []
for i, (batch) in enumerate(dataloader_test):
    scores.append(aenc_deep.batch_loss(batch.cuda(device = device)).data.cpu().numpy())
    encoder_out = aenc_deep.enc(batch.cuda(device = device))
reconstruction_mse  = np.mean(scores)

assert reconstruction_mse <= 0.005, "Compression is too lossy. See tips below."
assert len(encoder_out.shape)==2 and encoder_out.shape[1]==32, "Make sure encoder has code_size units"
print("Final MSE:", reconstruction_mse)
for i in range(5):
    img = X_test_tensor[i]
    visualize(img,aenc_deep)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/upsampling.py:129: UserWarning: nn.Upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.{} is deprecated. Use nn.functional.interpolate instead.".format(self.name))
# Final MSE: 0.004778803199222238

# %% [markdown]
# __Tips:__ If you keep getting "Compression to lossy" error, there's a few things you might try:
#
# * Make sure it converged. Some architectures need way more than 32 epochs to converge. They may fluctuate a lot, but eventually they're going to get good enough to pass. You may train your network for as long as you want.
#
# * Complexity. If you already have, like, 152 layers and still not passing threshold, you may wish to start from something simpler instead and go in small incremental steps.
#
# * Architecture. You can use any combination of layers (including convolutions, normalization, etc) as long as __encoder output only stores 32 numbers per training object__.
#
# A cunning learner can circumvent this last limitation by using some manual encoding strategy, but he is strongly recommended to avoid that.

# %% [markdown]
# ## Denoising AutoEncoder
#
# Let's now make our model into a denoising autoencoder.
#
# We'll keep your model architecture, but change the way it trains. In particular, we'll corrupt it's input data randomly before each epoch.
#
# There are many strategies to apply noise. We'll implement two popular one: adding gaussian noise and using dropout.

# %%
def apply_gaussian_noise(X,sigma=0.1):
    """
    adds noise from normal distribution with standard deviation sigma
    :param X: image tensor of shape [batch,height,width,3]
    """
        
    #<Your code: define noise>
    noise=np.random.normal(0,sigma,size=X.shape)
        
    return X + noise

# %% [markdown]
# **noise tests**

# %%
theoretical_std = (X[:100].std()**2 + 0.5**2)**.5
our_std = apply_gaussian_noise(X[:100],sigma=0.5).std()
assert abs(theoretical_std - our_std) < 0.01, "Standard deviation does not match it's required value. Make sure you use sigma as std."
assert abs(apply_gaussian_noise(X[:100],sigma=0.5).mean() - X[:100].mean()) < 0.01, "Mean has changed. Please add zero-mean noise"

# %%
plt.subplot(1,4,1)
plt.imshow(X[0].transpose([1,2,0]))
plt.subplot(1,4,2)
plt.imshow(apply_gaussian_noise(X[:1],sigma=0.01)[0].transpose([1,2,0]).clip(0, 1))
plt.subplot(1,4,3)
plt.imshow(apply_gaussian_noise(X[:1],sigma=0.1)[0].transpose([1,2,0]).clip(0, 1))
plt.subplot(1,4,4)
plt.imshow(apply_gaussian_noise(X[:1],sigma=0.5)[0].transpose([1,2,0]).clip(0, 1))

# %%
def train_noise(model, dataset, num_epoch=50):
    model.double()
    model.to(device)
    gd = optim.Adamax(model.parameters(), lr=0.002)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
    losses = []
    for epoch in range(num_epoch):
        for i, (batch) in enumerate(dataloader):
            noise_batch=apply_gaussian_noise(batch.data.numpy(),0.1)
            noise_batch=torch.tensor(noise_batch).double()
            gd.zero_grad()
            loss = model.batch_loss(batch.cuda(),noise_batch.cuda())
            (loss).backward()
            losses.append(loss.detach().cpu().numpy())
            gd.step()
            gd.zero_grad()
        print("#%i, Train loss: %.7f"%(epoch+1,np.mean(losses)),flush=True)

# %%
X_train_noise = apply_gaussian_noise(X_train)
X_test_noise = apply_gaussian_noise(X_test)

# %%
X_train_tensor_n = torch.from_numpy(X_train_noise).type(torch.DoubleTensor)
X_test_tensor_n = torch.Tensor(X_test_noise).type(torch.DoubleTensor)

# %%
aenc = pca_autoencoder()
train(aenc, X_train_tensor_n, 50)
# Out:
# #1, Train loss: 0.1669517
# #2, Train loss: 0.1011519
# #3, Train loss: 0.0782231
# #4, Train loss: 0.0666828
# #5, Train loss: 0.0597117
# #6, Train loss: 0.0550194
# #7, Train loss: 0.0516099
# #8, Train loss: 0.0489612
# #9, Train loss: 0.0467793
# #10, Train loss: 0.0448683
# #11, Train loss: 0.0431302
# #12, Train loss: 0.0415415
# #13, Train loss: 0.0400987
# #14, Train loss: 0.0387857
# #15, Train loss: 0.0375848
# #16, Train loss: 0.0364838
# #17, Train loss: 0.0354790
# #18, Train loss: 0.0345612
# #19, Train loss: 0.0337246
# #20, Train loss: 0.0329543
# #21, Train loss: 0.0322429
# #22, Train loss: 0.0315859
# #23, Train loss: 0.0309762
# #24, Train loss: 0.0304088
# #25, Train loss: 0.0298804
# #26, Train loss: 0.0293847
# #27, Train loss: 0.0289230
# #28, Train loss: 0.0284899
# #29, Train loss: 0.0280805
# #30, Train loss: 0.0276955
# #31, Train loss: 0.0273319
# #32, Train loss: 0.0269901
# #33, Train loss: 0.0266647
# #34, Train loss: 0.0263570
# #35, Train loss: 0.0260648
# #36, Train loss: 0.0257882
# #37, Train loss: 0.0255249
# #38, Train loss: 0.0252740
# #39, Train loss: 0.0250350
# #40, Train loss: 0.0248070
# #41, Train loss: 0.0245898
# #42, Train loss: 0.0243801
# #43, Train loss: 0.0241815
# #44, Train loss: 0.0239906
# #45, Train loss: 0.0238079
# #46, Train loss: 0.0236330
# #47, Train loss: 0.0234647
# #48, Train loss: 0.0233032
# #49, Train loss: 0.0231480
# #50, Train loss: 0.0229988

# %% [markdown]
# __Note:__ if it hasn't yet converged, increase the number of iterations.
#
# __Bonus:__ replace gaussian noise with masking random rectangles on image.

# %% [markdown]
# ** Let's evaluate!!! **

# %%
dataloader_test = DataLoader(X_test_tensor_n, batch_size=BATCH_SIZE, shuffle=True)
scores = []
for i, (batch) in enumerate(dataloader_test):
    scores.append(aenc.batch_loss(batch.cuda(device = device)).data.cpu().numpy())
    encoder_out = aenc.enc(batch.cuda(device = device))
reconstruction_mse  = np.mean(scores)

print("Final MSE:", reconstruction_mse)
for i in range(5):
    img = X_test_tensor_n[i]
    visualize(img,aenc)
# Out:
# Final MSE: 0.015778481390784024

# %% [markdown]
# ### Image retrieval with autoencoders
#
# So we've just trained a network that converts image into itself imperfectly. This task is not that useful in and of itself, but it has a number of awesome side-effects. Let's see it in action.
#
# First thing we can do is image retrieval aka image search. We we give it an image and find similar images in latent space.
#
# To speed up retrieval process, we shall use Locality-Sensitive Hashing on top of encoded vectors. We'll use scikit-learn's implementation for simplicity. In practical scenario, you may want to use [specialized libraries](https://erikbern.com/2015/07/04/benchmark-of-approximate-nearest-neighbor-libraries.html) for better performance and customization.

# %%
#encodes batch of images into a codes


codes = aenc.enc(X_train_tensor.to(device)).detach().cpu().numpy()

# %%
assert codes.shape[0] == X_train_tensor.shape[0]

# %%
from sklearn.neighbors import LSHForest
lshf = LSHForest(n_estimators=50).fit(codes)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/approximate.py:258: DeprecationWarning: LSHForest has poor performance and has been deprecated in 0.19. It will be removed in version 0.21.
#   DeprecationWarning)

# %%
images = torch.from_numpy(X_train).type(torch.DoubleTensor)

# %%
def get_similar(image, n_neighbors=5):
    assert len(image.shape)==3,"image must be [batch,height,width,3]"

    code = aenc.enc(image.cuda(device).view(1, *image.size())).cpu().detach().numpy()#aenc.enc(image.cuda(device)).detach().cpu().numpy()
    
    (distances,),(idx,) = lshf.kneighbors(code,n_neighbors=n_neighbors)#<Your code: using lshf.kneighbors find nearest neighbors>
    
    return distances,images[idx]

# %%
def show_similar(image):
    
    distances,neighbors = get_similar(image,n_neighbors=11)
    
    plt.figure(figsize=[8,6])
    plt.subplot(3,4,1)
    plt.imshow(image.cpu().numpy().transpose([1,2,0]))
    plt.title("Original image")
    
    for i in range(11):
        plt.subplot(3,4,i+2)
        plt.imshow(neighbors[i].cpu().numpy().transpose([1,2,0]))
        plt.title("Dist=%.3f"%distances[i])
    plt.show()

# %%
#smiles
show_similar(X_test_tensor[2])

# %%
#ethnicity
show_similar(X_test_tensor[500])

# %%
#glasses
show_similar(X_test_tensor[66])

# %% [markdown]
# ## Cheap image morphing

# %% [markdown]
# Here you should take two full-sized objects, code it and obtain intermediate object by decoding an intermixture code.
#
# $Code_{mixt} = a1\cdot code1 + a2\cdot code2$

# %%
for _ in range(5):
    image1,image2 =X_train_tensor[np.random.choice(range(X_train.shape[0]),2)]#<Your code:choose two image randomly>
    
    code1 = aenc.enc(image1.cuda(device).view(1, *image1.size()))#.cpu()#.detach().numpy()
    code2 = aenc.enc(image2.cuda(device).view(1, *image2.size()))#.cpu()#.detach().numpy()


    plt.figure(figsize=[10,4])
    for i,a in enumerate(np.linspace(0,1,num=7)):

        output_code = a*code1+(1-a)*code2#<Your code:define intermixture code>

        output_image = aenc.dec(output_code[None])[0]
        plt.subplot(1,7,i+1)
        plt.imshow(output_image.cpu().detach().numpy().transpose([1,2,0]))
        plt.title("a=%.2f"%a)
        
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Of course there's a lot more you can do with autoencoders.
#
# If you want to generate images from scratch, however, we recommend you our honor track seminar about generative adversarial networks.
